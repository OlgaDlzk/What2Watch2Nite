# %%
# Import dependencies
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read in Cleaned TV Show data
shows = pd.read_csv('../csv/tv_shows_data_cleaned.csv')
shows.head()
# Out:
#    id                        name               original_name genre_name  \
# 0  25           Star Wars: Droids           Star Wars: Droids       Kids
# 1  29  Mary Hartman, Mary Hartman  Mary Hartman, Mary Hartman      Drama
# 2  55                 North of 60                 North of 60      Drama
# 3  59           The European Side               Avrupa Yakası     Family
# 4  65                     The Job                     The Job      Drama
#
#    number_of_seasons  number_of_episodes first_air_date last_air_date  \
# 0                  1                13.0     1985-09-07    1985-11-30
# 1                  2               307.0     1976-01-05    1977-03-10
# 2                  6                95.0     1992-12-03    2005-01-30
# 3                  6               191.0     2004-02-11    2009-06-24
# 4                  2                19.0     2001-03-14    2002-04-24
#
#    in_production  popularity  ...  vote_count  origin_country  \
# 0          False      11.592  ...          66     ["CA","US"]
# 1          False      14.367  ...           8          ["US"]
# 2          False       5.742  ...          42          ["CA"]
# 3          False       7.568  ...          43          ["TR"]
# 4          False       6.335  ...          53          ["US"]
#
#   original_language                                           overview  \
# 0                en  An animated television series that features th...
# 1                en  In the fictional town of Fernwood, Ohio, subur...
# 2                en  North of 60 is a mid-1990s Canadian television...
# 3                tr  The life and times of rather traditional Sutcu...
# 4                en  Mike McNeil is a decorated New York City detec...
#
#   tagline                                      creator_names  \
# 0     NaN  ['George Lucas', 'Ben Burtt', 'Clive A. Smith'...
# 1     NaN  ['Gail Parent', 'Norman Lear', 'Ann Marcus', '...
# 2     NaN                                                NaN
# 3     NaN                                   ['Gülse Birsel']
# 4     NaN                     ['Denis Leary', 'Peter Tolan']
#
#                                     production_names  \
# 0          ['Lucasfilm Animation', 'Lucasfilm Ltd.']
# 1                     ['TAT Communications Company']
# 2                                                NaN
# 3                          ['Plato Film Production']
# 4  ['The Cloudland Company', 'Apostle', 'Touchsto...
#
#                                production_logo_paths  \
# 0  ['/eDWGeg5tdVNcI8aBaaJ21bEBtFa.png', '/o86Dbpb...
# 1                                             [None]
# 2                                                NaN
# 3                ['/XqfGZYm5Vk8rHEKkgx91XD3Ooy.png']
# 4  [None, None, '/wwaKUcOENHix2jxLfFBfNkCtOEQ.png...
#
#   production_origin_countries                       poster_path
# 0                ['US', 'US']  /b3gsZSTauRBJDJvWCbD9oVAsFe1.jpg
# 1                        ['']   /O1bcYEBW8v7JOMNVpYOBTL6PjL.jpg
# 2                         NaN  /twsoO8NCTitfW4My9wKz2p5yJou.jpg
# 3                      ['TR']   /4JSQb4uFPNLunGsS9FjY9wYhOj.jpg
# 4    ['US', 'US', 'US', 'US']   /iDiiIBZCjdihpBoDKzVRhb7C9B.jpg
#
# [5 rows x 21 columns]

# %%
# View datafram description
shows.describe()
# Out:
#                   id  number_of_seasons  number_of_episodes   popularity  \
# count    8421.000000        8421.000000         8420.000000  8421.000000
# mean    69218.841705           3.030044           68.168290    16.056712
# std     53088.012187           5.228819          285.915877    38.569410
# min         9.000000           1.000000            0.000000     0.600000
# 25%     22002.000000           1.000000            8.000000     3.770000
# 50%     66888.000000           1.000000           18.000000     7.265000
# 75%     96102.000000           3.000000           50.000000    14.985000
# max    225008.000000          79.000000         8903.000000  1075.970000
#
#        vote_average    vote_count
# count   8421.000000   8421.000000
# mean       7.136508    116.720698
# std        1.052547    577.350098
# min        1.400000      5.000000
# 25%        6.600000      7.000000
# 50%        7.250000     15.000000
# 75%        7.827000     46.000000
# max       10.000000  21048.000000

# %%
# View the dataframe data types
shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8421 entries, 0 to 8420
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           8421 non-null   int64
#  1   name                         8421 non-null   object
#  2   original_name                8421 non-null   object
#  3   genre_name                   8293 non-null   object
#  4   number_of_seasons            8421 non-null   int64
#  5   number_of_episodes           8420 non-null   float64
#  6   first_air_date               8410 non-null   object
#  7   last_air_date                8419 non-null   object
#  8   in_production                8421 non-null   bool
#  9   popularity                   8421 non-null   float64
#  10  vote_average                 8421 non-null   float64
#  11  vote_count                   8421 non-null   int64
#  12  origin_country               8421 non-null   object
#  13  original_language            8421 non-null   object
#  14  overview                     8216 non-null   object
#  15  tagline                      1203 non-null   object
#  16  creator_names                4392 non-null   object
#  17  production_names             6266 non-null   object
#  18  production_logo_paths        6266 non-null   object
#  19  production_origin_countries  6266 non-null   object
#  20  poster_path                  8377 non-null   object
# dtypes: bool(1), float64(3), int64(3), object(14)
# memory usage: 1.3+ MB

# %%
# Drop rows with null genre_name
shows.dropna(subset=['genre_name'], inplace=True)

# %%
# Change genre column to string
shows['genre_name'] = shows['genre_name'].astype(str)

# %%
# Review data types info
shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8293 entries, 0 to 8420
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           8293 non-null   int64
#  1   name                         8293 non-null   object
#  2   original_name                8293 non-null   object
#  3   genre_name                   8293 non-null   object
#  4   number_of_seasons            8293 non-null   int64
#  5   number_of_episodes           8292 non-null   float64
#  6   first_air_date               8284 non-null   object
#  7   last_air_date                8292 non-null   object
#  8   in_production                8293 non-null   bool
#  9   popularity                   8293 non-null   float64
#  10  vote_average                 8293 non-null   float64
#  11  vote_count                   8293 non-null   int64
#  12  origin_country               8293 non-null   object
#  13  original_language            8293 non-null   object
#  14  overview                     8090 non-null   object
#  15  tagline                      1195 non-null   object
#  16  creator_names                4348 non-null   object
#  17  production_names             6222 non-null   object
#  18  production_logo_paths        6222 non-null   object
#  19  production_origin_countries  6222 non-null   object
#  20  poster_path                  8250 non-null   object
# dtypes: bool(1), float64(3), int64(3), object(14)
# memory usage: 1.3+ MB

# %%
# Print out unique genres
unique_values = shows['genre_name'].unique()
print(unique_values)
# Out:
# ['Kids' 'Drama' 'Family' 'News' 'Comedy' 'Crime' 'Animation'
#  'Action & Adventure' 'Sci-Fi & Fantasy' 'Reality' 'Western' 'Documentary'
#  'Mystery' 'Talk' 'Soap' 'War & Politics' 'Romance' 'History']

# %%
# Plot the genres in terms of their occurrence to get an insight into TV genres popularity

plt.subplots(figsize=(12,10))
list1 = []
for i in shows['genre_name']:
    list1.extend(i)
ax = pd.Series(list1).value_counts()[:10].sort_values(ascending=True).plot.barh(width=0.9,
                                                                                color=sns.color_palette('hls',10))
for i, v in enumerate(pd.Series(list1).value_counts()[:10].sort_values(ascending=True).values): 
    ax.text(.8, i, v,fontsize=12,color='white',weight='bold')

plt.xlabel('Count')
plt.ylabel('Genre')
plt.title('Top Genres')
plt.show()

# %%
list1
# Out:
# ['K',
#  'i',
#  'd',
#  's',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'F',
#  'a',
#  'm',
#  'i',
#  'l',
#  'y',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'N',
#  'e',
#  'w',
#  's',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'r',
#  'i',
#  'm',
#  'e',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'A',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  '&',
#  ' ',
#  'A',
#  'd',
#  'v',
#  'e',
#  'n',
#  't',
#  'u',
#  'r',
#  'e',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'S',
#  'c',
#  'i',
#  '-',
#  'F',
#  'i',
#  ' ',
#  '&',
#  ' ',
#  'F',
#  'a',
#  'n',
#  't',
#  'a',
#  's',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'R',
#  'e',
#  'a',
#  'l',
#  'i',
#  't',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'W',
#  'e',
#  's',
#  't',
#  'e',
#  'r',
#  'n',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'D',
#  'o',
#  'c',
#  'u',
#  'm',
#  'e',
#  'n',
#  't',
#  'a',
#  'r',
#  'y',
#  'N',
#  'e',
#  'w',
#  's',
#  'R',
#  'e',
#  'a',
#  'l',
#  'i',
#  't',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'S',
#  'c',
#  'i',
#  '-',
#  'F',
#  'i',
#  ' ',
#  '&',
#  ' ',
#  'F',
#  'a',
#  'n',
#  't',
#  'a',
#  's',
#  'y',
#  'A',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  '&',
#  ' ',
#  'A',
#  'd',
#  'v',
#  'e',
#  'n',
#  't',
#  'u',
#  'r',
#  'e',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'F',
#  'a',
#  'm',
#  'i',
#  'l',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'A',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  '&',
#  ' ',
#  'A',
#  'd',
#  'v',
#  'e',
#  'n',
#  't',
#  'u',
#  'r',
#  'e',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'A',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  '&',
#  ' ',
#  'A',
#  'd',
#  'v',
#  'e',
#  'n',
#  't',
#  'u',
#  'r',
#  'e',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'F',
#  'a',
#  'm',
#  'i',
#  'l',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'F',
#  'a',
#  'm',
#  'i',
#  'l',
#  'y',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'K',
#  'i',
#  'd',
#  's',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'A',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  '&',
#  ' ',
#  'A',
#  'd',
#  'v',
#  'e',
#  'n',
#  't',
#  'u',
#  'r',
#  'e',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'A',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  '&',
#  ' ',
#  'A',
#  'd',
#  'v',
#  'e',
#  'n',
#  't',
#  'u',
#  'r',
#  'e',
#  'M',
#  'y',
#  's',
#  't',
#  'e',
#  'r',
#  'y',
#  'A',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  '&',
#  ' ',
#  'A',
#  'd',
#  'v',
#  'e',
#  'n',
#  't',
#  'u',
#  'r',
#  'e',
#  'A',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  '&',
#  ' ',
#  'A',
#  'd',
#  'v',
#  'e',
#  'n',
#  't',
#  'u',
#  'r',
#  'e',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'T',
#  'a',
#  'l',
#  'k',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'T',
#  'a',
#  'l',
#  'k',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'A',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  '&',
#  ' ',
#  'A',
#  'd',
#  'v',
#  'e',
#  'n',
#  't',
#  'u',
#  'r',
#  'e',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'T',
#  'a',
#  'l',
#  'k',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'S',
#  'o',
#  'a',
#  'p',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'R',
#  'e',
#  'a',
#  'l',
#  'i',
#  't',
#  'y',
#  'R',
#  'e',
#  'a',
#  'l',
#  'i',
#  't',
#  'y',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'S',
#  'c',
#  'i',
#  '-',
#  'F',
#  'i',
#  ' ',
#  '&',
#  ' ',
#  'F',
#  'a',
#  'n',
#  't',
#  'a',
#  's',
#  'y',
#  'A',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  '&',
#  ' ',
#  'A',
#  'd',
#  'v',
#  'e',
#  'n',
#  't',
#  'u',
#  'r',
#  'e',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'R',
#  'e',
#  'a',
#  'l',
#  'i',
#  't',
#  'y',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'T',
#  'a',
#  'l',
#  'k',
#  'R',
#  'e',
#  'a',
#  'l',
#  'i',
#  't',
#  'y',
#  'R',
#  'e',
#  'a',
#  'l',
#  'i',
#  't',
#  'y',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'A',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  '&',
#  ' ',
#  'A',
#  'd',
#  'v',
#  'e',
#  'n',
#  't',
#  'u',
#  'r',
#  'e',
#  'D',
#  'r',
#  'a',
#  'm',
#  'a',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'A',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  '&',
#  ' ',
#  'A',
#  'd',
#  'v',
#  'e',
#  'n',
#  't',
#  'u',
#  'r',
#  'e',
#  'T',
#  'a',
#  'l',
#  'k',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'S',
#  'c',
#  'i',
#  '-',
#  'F',
#  'i',
#  ' ',
#  '&',
#  ' ',
#  'F',
#  'a',
#  'n',
#  't',
#  'a',
#  's',
#  'y',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'F',
#  'a',
#  'm',
#  'i',
#  'l',
#  'y',
#  'A',
#  'c',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  '&',
#  ' ',
#  'A',
#  'd',
#  'v',
#  'e',
#  'n',
#  't',
#  'u',
#  'r',
#  'e',
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  'C',
#  ...]

# %%
# Clean the genre column to create a genre list
# shows['genre_name'] = shows['genre_name'].str.strip('[]').str.replace(' ','').str.replace("'",'')
# shows['genre_name'] = shows['genre_name'].str.split(',')
